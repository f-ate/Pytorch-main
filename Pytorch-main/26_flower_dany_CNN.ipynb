# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL #pillow to handle images
import tensorflow as tf

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz" #tgz = tar ball (just like zip file)
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 1s 0us/step
# 228827136/228813984 [==============================] - 1s 0us/step

# %%
valid_size = .2

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
import time

# %%
# Normalize the test and train sets with torchvision
train_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(30),
    transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

valid_transforms = transforms.Compose([transforms.Resize((224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(
                                       mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                          ])

# %%
NUM_EPOCHS = 10
lr = 0.001
batch_size = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
DEVICE
# Out:
# device(type='cuda')

# %%
# ImageFolder class to load the train and test images
train_data = datasets.ImageFolder(data_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(data_dir, transform=valid_transforms)

# %%
# Number of train images
num_train = len(train_data)
indices = list(range(num_train))

# %%
# Split = 20% of train images
split = int(np.floor(valid_size * num_train))
# Shuffle indices of train images
np.random.shuffle(indices)

# %%
# Subset indices for test and train
train_idx, valid_idx = indices[split:], indices[:split]

# %%
# Samples elements randomly from a given list of indices
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
# Batch and load the images
train_loader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(valid_data, sampler=valid_sampler, batch_size=batch_size)

# %%
examples = iter(train_loader)
samples ,labels = examples.next()
samples.shape
# Out:
# torch.Size([32, 3, 224, 224])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
for i in range(4):
    plt.subplot(2,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(samples[i][0])
plt.show()

# %%
def imshow(img,title):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(25,20))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title(title)
    plt.show()

# %%
sample = samples[:4]
label = labels[:4]
out = torchvision.utils.make_grid(sample)

# %%
class_name = train_data.classes

# %%
imshow(out,title=[class_name[x] for x in label])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def imshow(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(8,8))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    #plt.title(title)
    plt.show()
imshow(samples[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = nn.Sequential(nn.Conv2d(3,32,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(32,64,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(128,128,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Conv2d(128,256,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Flatten(),
                     nn.Linear(256*28*28,512),
                     nn.ReLU(),
                     nn.Linear(512,256),
                     nn.ReLU(),
                     nn.Linear(256,5))

# %%
model = model.to(DEVICE)

# %%
#criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
def compute_accuracy(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100


start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        probas = model(features)
        cost = F.cross_entropy(probas, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 4:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/010 | Batch 000/092 | Cost: 0.9801
# Epoch: 001/010 | Batch 004/092 | Cost: 1.0076
# Epoch: 001/010 | Batch 008/092 | Cost: 0.8452
# Epoch: 001/010 | Batch 012/092 | Cost: 0.9006
# Epoch: 001/010 | Batch 016/092 | Cost: 1.0693
# Epoch: 001/010 | Batch 020/092 | Cost: 0.7431
# Epoch: 001/010 | Batch 024/092 | Cost: 1.0302
# Epoch: 001/010 | Batch 028/092 | Cost: 1.0197
# Epoch: 001/010 | Batch 032/092 | Cost: 0.9840
# Epoch: 001/010 | Batch 036/092 | Cost: 1.1010
# Epoch: 001/010 | Batch 040/092 | Cost: 0.9857
# Epoch: 001/010 | Batch 044/092 | Cost: 0.7533
# Epoch: 001/010 | Batch 048/092 | Cost: 0.9144
# Epoch: 001/010 | Batch 052/092 | Cost: 0.9810
# Epoch: 001/010 | Batch 056/092 | Cost: 1.1646
# Epoch: 001/010 | Batch 060/092 | Cost: 0.8858
# Epoch: 001/010 | Batch 064/092 | Cost: 0.9160
# Epoch: 001/010 | Batch 068/092 | Cost: 0.9713
# Epoch: 001/010 | Batch 072/092 | Cost: 0.8917
# Epoch: 001/010 | Batch 076/092 | Cost: 1.0051
# Epoch: 001/010 | Batch 080/092 | Cost: 0.7407
# Epoch: 001/010 | Batch 084/092 | Cost: 1.0905
# Epoch: 001/010 | Batch 088/092 | Cost: 0.7364
# Epoch: 001/010 Train Acc.: 65.05% | Validation Acc.: 63.49%
# Time elapsed: 0.99 min
# Epoch: 002/010 | Batch 000/092 | Cost: 0.9484
# Epoch: 002/010 | Batch 004/092 | Cost: 0.8440
# Epoch: 002/010 | Batch 008/092 | Cost: 0.7241
# Epoch: 002/010 | Batch 012/092 | Cost: 0.8172
# Epoch: 002/010 | Batch 016/092 | Cost: 1.2560
# Epoch: 002/010 | Batch 020/092 | Cost: 0.9603
# Epoch: 002/010 | Batch 024/092 | Cost: 0.8849
# Epoch: 002/010 | Batch 028/092 | Cost: 0.7340
# Epoch: 002/010 | Batch 032/092 | Cost: 0.9157
# Epoch: 002/010 | Batch 036/092 | Cost: 0.8167
# Epoch: 002/010 | Batch 040/092 | Cost: 0.9849
# Epoch: 002/010 | Batch 044/092 | Cost: 0.9239
# Epoch: 002/010 | Batch 048/092 | Cost: 1.1219
# Epoch: 002/010 | Batch 052/092 | Cost: 1.3395
# Epoch: 002/010 | Batch 056/092 | Cost: 0.6788
# Epoch: 002/010 | Batch 060/092 | Cost: 0.9797
# Epoch: 002/010 | Batch 064/092 | Cost: 0.9477
# Epoch: 002/010 | Batch 068/092 | Cost: 0.7182
# Epoch: 002/010 | Batch 072/092 | Cost: 0.8265
# Epoch: 002/010 | Batch 076/092 | Cost: 0.8382
# Epoch: 002/010 | Batch 080/092 | Cost: 0.7380
# Epoch: 002/010 | Batch 084/092 | Cost: 0.8273
# Epoch: 002/010 | Batch 088/092 | Cost: 0.7388
# Epoch: 002/010 Train Acc.: 66.45% | Validation Acc.: 66.49%
# Time elapsed: 1.95 min
# Epoch: 003/010 | Batch 000/092 | Cost: 0.7045
# Epoch: 003/010 | Batch 004/092 | Cost: 1.0187
# Epoch: 003/010 | Batch 008/092 | Cost: 0.6632
# Epoch: 003/010 | Batch 012/092 | Cost: 1.1316
# Epoch: 003/010 | Batch 016/092 | Cost: 0.6265
# Epoch: 003/010 | Batch 020/092 | Cost: 0.8978
# Epoch: 003/010 | Batch 024/092 | Cost: 0.8229
# Epoch: 003/010 | Batch 028/092 | Cost: 0.5425
# Epoch: 003/010 | Batch 032/092 | Cost: 1.0208
# Epoch: 003/010 | Batch 036/092 | Cost: 1.1954
# Epoch: 003/010 | Batch 040/092 | Cost: 0.8737
# Epoch: 003/010 | Batch 044/092 | Cost: 1.0228
# Epoch: 003/010 | Batch 048/092 | Cost: 0.7245
# Epoch: 003/010 | Batch 052/092 | Cost: 0.7748
# Epoch: 003/010 | Batch 056/092 | Cost: 0.5998
# Epoch: 003/010 | Batch 060/092 | Cost: 1.0527
# Epoch: 003/010 | Batch 064/092 | Cost: 0.7743
# Epoch: 003/010 | Batch 068/092 | Cost: 0.8118
# Epoch: 003/010 | Batch 072/092 | Cost: 0.6384
# Epoch: 003/010 | Batch 076/092 | Cost: 1.0340
# Epoch: 003/010 | Batch 080/092 | Cost: 0.7472
# Epoch: 003/010 | Batch 084/092 | Cost: 0.8890
# Epoch: 003/010 | Batch 088/092 | Cost: 1.1139
# Epoch: 003/010 Train Acc.: 67.47% | Validation Acc.: 64.58%
# Time elapsed: 2.92 min
# Epoch: 004/010 | Batch 000/092 | Cost: 1.0040
# Epoch: 004/010 | Batch 004/092 | Cost: 0.5565
# Epoch: 004/010 | Batch 008/092 | Cost: 0.8805
# Epoch: 004/010 | Batch 012/092 | Cost: 0.6594
# Epoch: 004/010 | Batch 016/092 | Cost: 0.7008
# Epoch: 004/010 | Batch 020/092 | Cost: 0.5968
# Epoch: 004/010 | Batch 024/092 | Cost: 0.9854
# Epoch: 004/010 | Batch 028/092 | Cost: 0.8825
# Epoch: 004/010 | Batch 032/092 | Cost: 0.7846
# Epoch: 004/010 | Batch 036/092 | Cost: 0.7236
# Epoch: 004/010 | Batch 040/092 | Cost: 0.9123
# Epoch: 004/010 | Batch 044/092 | Cost: 0.6556
# Epoch: 004/010 | Batch 048/092 | Cost: 1.1073
# Epoch: 004/010 | Batch 052/092 | Cost: 1.2840
# Epoch: 004/010 | Batch 056/092 | Cost: 1.1933
# Epoch: 004/010 | Batch 060/092 | Cost: 1.0691
# Epoch: 004/010 | Batch 064/092 | Cost: 1.0901
# Epoch: 004/010 | Batch 068/092 | Cost: 0.6725
# Epoch: 004/010 | Batch 072/092 | Cost: 0.6492
# Epoch: 004/010 | Batch 076/092 | Cost: 0.7911
# Epoch: 004/010 | Batch 080/092 | Cost: 0.8661
# Epoch: 004/010 | Batch 084/092 | Cost: 0.5394
# Epoch: 004/010 | Batch 088/092 | Cost: 1.0001
# Epoch: 004/010 Train Acc.: 69.86% | Validation Acc.: 68.26%
# Time elapsed: 3.88 min
# Epoch: 005/010 | Batch 000/092 | Cost: 0.6764
# Epoch: 005/010 | Batch 004/092 | Cost: 1.0811
# Epoch: 005/010 | Batch 008/092 | Cost: 0.9143
# Epoch: 005/010 | Batch 012/092 | Cost: 0.8975
# Epoch: 005/010 | Batch 016/092 | Cost: 0.7676
# Epoch: 005/010 | Batch 020/092 | Cost: 0.7886
# Epoch: 005/010 | Batch 024/092 | Cost: 1.0424
# Epoch: 005/010 | Batch 028/092 | Cost: 0.6229
# Epoch: 005/010 | Batch 032/092 | Cost: 0.9553
# Epoch: 005/010 | Batch 036/092 | Cost: 0.9519
# Epoch: 005/010 | Batch 040/092 | Cost: 0.7823
# Epoch: 005/010 | Batch 044/092 | Cost: 0.7961
# Epoch: 005/010 | Batch 048/092 | Cost: 0.7434
# Epoch: 005/010 | Batch 052/092 | Cost: 1.2751
# Epoch: 005/010 | Batch 056/092 | Cost: 1.4424
# Epoch: 005/010 | Batch 060/092 | Cost: 0.6296
# Epoch: 005/010 | Batch 064/092 | Cost: 0.7211
# Epoch: 005/010 | Batch 068/092 | Cost: 0.7613
# Epoch: 005/010 | Batch 072/092 | Cost: 0.6083
# Epoch: 005/010 | Batch 076/092 | Cost: 0.7574
# Epoch: 005/010 | Batch 080/092 | Cost: 1.2114
# Epoch: 005/010 | Batch 084/092 | Cost: 0.6518
# Epoch: 005/010 | Batch 088/092 | Cost: 0.8278
# Epoch: 005/010 Train Acc.: 69.82% | Validation Acc.: 67.57%
# Time elapsed: 4.83 min
# Epoch: 006/010 | Batch 000/092 | Cost: 0.9457
# Epoch: 006/010 | Batch 004/092 | Cost: 0.8753
# Epoch: 006/010 | Batch 008/092 | Cost: 1.0041
# Epoch: 006/010 | Batch 012/092 | Cost: 0.6825
# Epoch: 006/010 | Batch 016/092 | Cost: 0.9127
# Epoch: 006/010 | Batch 020/092 | Cost: 0.6752
# Epoch: 006/010 | Batch 024/092 | Cost: 0.9098
# Epoch: 006/010 | Batch 028/092 | Cost: 0.7230
# Epoch: 006/010 | Batch 032/092 | Cost: 0.7869
# Epoch: 006/010 | Batch 036/092 | Cost: 0.9297
# Epoch: 006/010 | Batch 040/092 | Cost: 0.5936
# Epoch: 006/010 | Batch 044/092 | Cost: 0.8476
# Epoch: 006/010 | Batch 048/092 | Cost: 0.6749
# Epoch: 006/010 | Batch 052/092 | Cost: 0.7896
# Epoch: 006/010 | Batch 056/092 | Cost: 0.8644
# Epoch: 006/010 | Batch 060/092 | Cost: 0.7208
# Epoch: 006/010 | Batch 064/092 | Cost: 0.5560
# Epoch: 006/010 | Batch 068/092 | Cost: 0.8778
# Epoch: 006/010 | Batch 072/092 | Cost: 0.7208
# Epoch: 006/010 | Batch 076/092 | Cost: 0.7728
# Epoch: 006/010 | Batch 080/092 | Cost: 0.7035
# Epoch: 006/010 | Batch 084/092 | Cost: 0.7249
# Epoch: 006/010 | Batch 088/092 | Cost: 0.6912
# Epoch: 006/010 Train Acc.: 69.28% | Validation Acc.: 67.98%
# Time elapsed: 5.79 min
# Epoch: 007/010 | Batch 000/092 | Cost: 0.8700
# Epoch: 007/010 | Batch 004/092 | Cost: 0.7205
# Epoch: 007/010 | Batch 008/092 | Cost: 0.6070
# Epoch: 007/010 | Batch 012/092 | Cost: 0.6367
# Epoch: 007/010 | Batch 016/092 | Cost: 1.0958
# Epoch: 007/010 | Batch 020/092 | Cost: 0.6294
# Epoch: 007/010 | Batch 024/092 | Cost: 0.6886
# Epoch: 007/010 | Batch 028/092 | Cost: 0.7952
# Epoch: 007/010 | Batch 032/092 | Cost: 0.8233
# Epoch: 007/010 | Batch 036/092 | Cost: 0.7379
# Epoch: 007/010 | Batch 040/092 | Cost: 1.0731
# Epoch: 007/010 | Batch 044/092 | Cost: 0.7329
# Epoch: 007/010 | Batch 048/092 | Cost: 1.0877
# Epoch: 007/010 | Batch 052/092 | Cost: 0.6776
# Epoch: 007/010 | Batch 056/092 | Cost: 0.8904
# Epoch: 007/010 | Batch 060/092 | Cost: 0.6859
# Epoch: 007/010 | Batch 064/092 | Cost: 0.6663
# Epoch: 007/010 | Batch 068/092 | Cost: 0.7467
# Epoch: 007/010 | Batch 072/092 | Cost: 0.8338
# Epoch: 007/010 | Batch 076/092 | Cost: 0.5856
# Epoch: 007/010 | Batch 080/092 | Cost: 0.5688
# Epoch: 007/010 | Batch 084/092 | Cost: 0.7670
# Epoch: 007/010 | Batch 088/092 | Cost: 0.5117
# Epoch: 007/010 Train Acc.: 71.39% | Validation Acc.: 68.80%
# Time elapsed: 6.75 min
# Epoch: 008/010 | Batch 000/092 | Cost: 0.7851
# Epoch: 008/010 | Batch 004/092 | Cost: 0.8602
# Epoch: 008/010 | Batch 008/092 | Cost: 0.4825
# Epoch: 008/010 | Batch 012/092 | Cost: 0.6742
# Epoch: 008/010 | Batch 016/092 | Cost: 0.8494
# Epoch: 008/010 | Batch 020/092 | Cost: 0.8313
# Epoch: 008/010 | Batch 024/092 | Cost: 0.9049
# Epoch: 008/010 | Batch 028/092 | Cost: 0.7334
# Epoch: 008/010 | Batch 032/092 | Cost: 0.7304
# Epoch: 008/010 | Batch 036/092 | Cost: 0.6607
# Epoch: 008/010 | Batch 040/092 | Cost: 0.8381
# Epoch: 008/010 | Batch 044/092 | Cost: 0.9425
# Epoch: 008/010 | Batch 048/092 | Cost: 1.1107
# Epoch: 008/010 | Batch 052/092 | Cost: 0.7410
# Epoch: 008/010 | Batch 056/092 | Cost: 0.6151
# Epoch: 008/010 | Batch 060/092 | Cost: 0.9168
# Epoch: 008/010 | Batch 064/092 | Cost: 0.7017
# Epoch: 008/010 | Batch 068/092 | Cost: 0.6442
# Epoch: 008/010 | Batch 072/092 | Cost: 1.0037
# Epoch: 008/010 | Batch 076/092 | Cost: 0.5308
# Epoch: 008/010 | Batch 080/092 | Cost: 0.6145
# Epoch: 008/010 | Batch 084/092 | Cost: 0.6617
# Epoch: 008/010 | Batch 088/092 | Cost: 0.5573
# Epoch: 008/010 Train Acc.: 71.73% | Validation Acc.: 68.94%
# Time elapsed: 7.71 min
# Epoch: 009/010 | Batch 000/092 | Cost: 0.7394
# Epoch: 009/010 | Batch 004/092 | Cost: 0.4681
# Epoch: 009/010 | Batch 008/092 | Cost: 0.7171
# Epoch: 009/010 | Batch 012/092 | Cost: 0.8525
# Epoch: 009/010 | Batch 016/092 | Cost: 0.5119
# Epoch: 009/010 | Batch 020/092 | Cost: 0.6070
# Epoch: 009/010 | Batch 024/092 | Cost: 0.7635
# Epoch: 009/010 | Batch 028/092 | Cost: 0.6415
# Epoch: 009/010 | Batch 032/092 | Cost: 0.8421
# Epoch: 009/010 | Batch 036/092 | Cost: 0.8443
# Epoch: 009/010 | Batch 040/092 | Cost: 0.7421
# Epoch: 009/010 | Batch 044/092 | Cost: 0.6974
# Epoch: 009/010 | Batch 048/092 | Cost: 0.8315
# Epoch: 009/010 | Batch 052/092 | Cost: 0.6417
# Epoch: 009/010 | Batch 056/092 | Cost: 0.7953
# Epoch: 009/010 | Batch 060/092 | Cost: 0.6736
# Epoch: 009/010 | Batch 064/092 | Cost: 0.7729
# Epoch: 009/010 | Batch 068/092 | Cost: 0.6440
# Epoch: 009/010 | Batch 072/092 | Cost: 0.7293
# Epoch: 009/010 | Batch 076/092 | Cost: 1.0601
# Epoch: 009/010 | Batch 080/092 | Cost: 0.8186
# Epoch: 009/010 | Batch 084/092 | Cost: 0.5190
# Epoch: 009/010 | Batch 088/092 | Cost: 0.6728
# Epoch: 009/010 Train Acc.: 73.43% | Validation Acc.: 69.75%
# Time elapsed: 8.66 min
# Epoch: 010/010 | Batch 000/092 | Cost: 0.6856
# Epoch: 010/010 | Batch 004/092 | Cost: 0.5878
# Epoch: 010/010 | Batch 008/092 | Cost: 0.6524
# Epoch: 010/010 | Batch 012/092 | Cost: 0.7628
# Epoch: 010/010 | Batch 016/092 | Cost: 0.5487
# Epoch: 010/010 | Batch 020/092 | Cost: 0.7412
# Epoch: 010/010 | Batch 024/092 | Cost: 0.5233
# Epoch: 010/010 | Batch 028/092 | Cost: 0.7681
# Epoch: 010/010 | Batch 032/092 | Cost: 0.4518
# Epoch: 010/010 | Batch 036/092 | Cost: 0.7878
# Epoch: 010/010 | Batch 040/092 | Cost: 0.9706
# Epoch: 010/010 | Batch 044/092 | Cost: 0.5506
# Epoch: 010/010 | Batch 048/092 | Cost: 0.7999
# Epoch: 010/010 | Batch 052/092 | Cost: 0.8559
# Epoch: 010/010 | Batch 056/092 | Cost: 0.6789
# Epoch: 010/010 | Batch 060/092 | Cost: 0.5598
# Epoch: 010/010 | Batch 064/092 | Cost: 0.8555
# Epoch: 010/010 | Batch 068/092 | Cost: 0.5419
# Epoch: 010/010 | Batch 072/092 | Cost: 0.8565
# Epoch: 010/010 | Batch 076/092 | Cost: 0.8191
# Epoch: 010/010 | Batch 080/092 | Cost: 0.8931
# Epoch: 010/010 | Batch 084/092 | Cost: 0.9851
# Epoch: 010/010 | Batch 088/092 | Cost: 0.6071
# Epoch: 010/010 Train Acc.: 71.15% | Validation Acc.: 67.03%
# Time elapsed: 9.62 min
# Total Training Time: 9.62 min
